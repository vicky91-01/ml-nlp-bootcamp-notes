# %%
age = int(input("enter your age"))

print("age",age)
print(type(age))
# Out:
# age 4
# <class 'int'>

# %%
number = float(input("enter a number"))

if(number < 0):
    print("negative ")
if(number > 0):
    print("positive number")
else:
    print("zero")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 number = float(input("enter a number"))
#       2
#       3 if(number < 0):
#       4     print("negative ")
#
# File d:\ml-nlp-bootcamp-notes\venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File d:\ml-nlp-bootcamp-notes\venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
# ...

# %%
n1 = 2;
n2 = 3;
n4 = 4;

if(n1 > n2 & n1 > n4):
    print(n1)
if(n2 > n1 & n2 > n4):
    print(n2)
else:
    print(f"{n4}")
# Out:
# 4
